# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,r2_score
import json as js
import requests
import statsmodels.tsa.arima.model as ARIMA

# %%
# Chargement du fichier CSV
# Remplace "ton_fichier.csv" par le nom réel de ton fichier CSV
df = pd.read_csv('/home/la-mus/AI/Data/monthly-temperature.lubumbashi.1993-2024.csv')
df.head()

# %%
#ici on vas choisir le climat a predire et definir x
x = df[[ 'Month','Year','Max Temperature','Min Temperature']]
y =df [['Max Temperature','Min Temperature']]

# %%
df['Max Temperature'].plot()
plt.show()

# %%
df['Year'].plot()
plt.show()

# %%
# analyse de dimension combien de ligne combien de colonne
df.shape

# %%
df.info()

# %%
#supression de ligne avec NaN
df = df.dropna()
# serapre le donne 
x= df[['Year','Month','Max Temperature','Min Temperature']]
y= df[['Average Temperature']]

# %%
#Vérifier les données manquantes dans chaque colonne
df.isnull().sum()

# %%
df.describe(include="all") # veux dire a la fois de valeur quanti et quel

# %%
scaler = MinMaxScaler()
df[['Year_scaled']] = scaler.fit_transform(df[['Year']])
df[['Max Temperature_scaled']] = scaler.fit_transform(df[['Max Temperature']])
df[['Min Temperature_scaled']] = scaler.fit_transform(df[['Min Temperature']])

# %%
#ici on vas cherche a entraine notre modele 
# x= variable explication et y =à variable a predire
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit=(x_train,y_train)
x_train = df[["Year","Month","Max Temperature","Min Temperature"]]
print("model entraine avec succes")

# %%
#modelisation
scaled =  MinMaxScaler.transform()
model = LinearRegression()
model.fit(x_scaled_y)

# %%
#prediction
data= pd.DataFrame({
    "Year":[2026,2027,2028,2029,2030],
    "Month":[12,12,12,12,12],
     "Max Temperature":[0,0,0,0,0], 
    "Min Temperature":[0,0,0,0,0]
    
})
data_scaled = scaler.transform(data)
pred = model.predict(data_scaled)
print(pred)

# %%
y_pred = model.predict(x)  # prédiction sur toutes les années
threshold = 2  # exagération si > prédiction + 2°C
colors = ['red' if actual > pred + threshold else 'blue' for actual, pred in zip(y, y_pred)]
plt.figure(figsize=(12,6))
plt.scatter(df['Year'], y, c=colors)
plt.plot(df['Year'], y_pred, color='green', label='Prédiction modèle')
plt.xlabel("Année")
plt.ylabel("Température max")
plt.title("Climat : max temp vs prédiction")
plt.legend()
plt.show()

# %%
# ici on vas importe le paque d'une maniere que url touche le toekn du gemini pour donne du conseil en fonction de 
#prediction
url='https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent?key=VOTRE_CLE'
headers = {
    'content-type':"application/jeson"
}
data={
    "content-type":[{"parts":
        [{
           "text": "Alyse cette courbe temperature(1.5°C/an) et conseille soluion climatique"
        }]
    }]
}
reponse = requests.post(url,headers=headers,json=data)
print("jeson.dumps(response.json(),indent=2")
plt.show()

# %%
print(scaler.feature_names_in_)

# %%
print(df["Month"].dtype)
