# %%
from pyicloud import PyiCloudService

# %%
from pyicloud import PyiCloudService

api = PyiCloudService('musjosue809@icloud.com', 'Seraphine wandy 123@')

if api.requires_2fa:
    print("Code 2FA envoyé à tes appareils.")
    code = input("Entre le code 2FA : ")
    result = api.validate_2fa_code(code)
    print("Validé :", result)

device = api.iphone
location = device.location
print("Latitude :", location['latitude'])
print("Longitude :", location['longitude'])
# Out:
# ---------------------------------------------------------------------------
# PyiCloudFailedLoginException              Traceback (most recent call last)
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:265, in PyiCloudService._authenticate(self)
#     264 try:
# --> 265     self._authenticate_with_token()
#     266 except (PyiCloudFailedLoginException, PyiCloud2FARequiredException):
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:343, in PyiCloudService._authenticate_with_token(self)
#     342 if not self.session.data.get("session_token"):
# --> 343     raise PyiCloudFailedLoginException("No session token available")
#     345 try:
#
# PyiCloudFailedLoginException: No session token available
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File ~/AI/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/AI/lib/python3.13/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.13/socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/AI/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/AI/lib/python3.13/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/AI/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/AI/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/AI/lib/python3.13/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File ~/AI/lib/python3.13/site-packages/urllib3/connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x77e47452dd30>: Failed to resolve 'idmsa.apple.com' ([Errno -3] Temporary failure in name resolution)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/AI/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/AI/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/AI/lib/python3.13/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='idmsa.apple.com', port=443): Max retries exceeded with url: /appleauth/auth/signin/init (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x77e47452dd30>: Failed to resolve 'idmsa.apple.com' ([Errno -3] Temporary failure in name resolution)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/AI/lib/python3.13/site-packages/pyicloud/session.py:192, in PyiCloudSession._request(self, method, url, data, has_retried, **kwargs)
#     191 try:
# --> 192     response: Response = super().request(
#     193         method=method,
#     194         url=url,
#     195         data=data,
#     196         **kwargs,
#     197     )
#     199     self._update_session_data(response)
#
# File ~/AI/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/AI/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/AI/lib/python3.13/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='idmsa.apple.com', port=443): Max retries exceeded with url: /appleauth/auth/signin/init (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x77e47452dd30>: Failed to resolve 'idmsa.apple.com' ([Errno -3] Temporary failure in name resolution)"))
#
# The above exception was the direct cause of the following exception:
#
# PyiCloudAPIResponseException              Traceback (most recent call last)
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:294, in PyiCloudService._srp_authentication(self, headers)
#     293 try:
# --> 294     response: Response = self.session.post(
#     295         f"{self.auth_endpoint}/signin/init",
#     296         json=data,
#     297         headers=headers,
#     298     )
#     299     response.raise_for_status()
#
# File ~/AI/lib/python3.13/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     627 r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629 :param url: URL for the new :class:`Request` object.
#    (...)    634 :rtype: requests.Response
#     635 """
# --> 637 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/session.py:155, in PyiCloudSession.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     136 def request(
#     137     self,
#     138     method,
#    (...)    153     json=None,
#     154 ) -> Response:
# --> 155     return self._request(
#     156         method,
#     157         url,
#     158         params=params,
#     159         data=data,
#     160         headers=headers,
#     161         cookies=cookies,
#     162         files=files,
#     163         auth=auth,
#     164         timeout=timeout,
#     165         allow_redirects=allow_redirects,
#     166         proxies=proxies,
#     167         hooks=hooks,
#     168         stream=stream,
#     169         verify=verify,
#     170         cert=cert,
#     171         json=json,
#     172     )
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/session.py:229, in PyiCloudSession._request(self, method, url, data, has_retried, **kwargs)
#     228 except requests.exceptions.RequestException as err:
# --> 229     raise PyiCloudAPIResponseException("Request failed to iCloud") from err
#
# PyiCloudAPIResponseException: Request failed to iCloud
#
# The above exception was the direct cause of the following exception:
#
# PyiCloudFailedLoginException              Traceback (most recent call last)
# Cell In[2], line 3
#       1 from pyicloud import PyiCloudService
# ----> 3 api = PyiCloudService('musjosue809@icloud.com', 'Seraphine wandy 123@')
#       5 if api.requires_2fa:
#       6     print("Code 2FA envoyé à tes appareils.")
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:205, in PyiCloudService.__init__(self, apple_id, password, cookie_directory, verify, client_id, with_family, china_mainland)
#     202 self._photos: Optional[PhotosService] = None
#     203 self._reminders: Optional[RemindersService] = None
# --> 205 self.authenticate()
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:241, in PyiCloudService.authenticate(self, force_refresh, service)
#     239 if not login_successful:
#     240     try:
# --> 241         self._authenticate()
#     242     except PyiCloud2FARequiredException:
#     243         LOGGER.debug("2FA is required")
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:269, in PyiCloudService._authenticate(self)
#     266 except (PyiCloudFailedLoginException, PyiCloud2FARequiredException):
#     267     headers: dict[str, str] = self._get_auth_headers()
# --> 269     self._srp_authentication(headers)
#     270     self._authenticate_with_token()
#
# File ~/AI/lib/python3.13/site-packages/pyicloud/base.py:302, in PyiCloudService._srp_authentication(self, headers)
#     300 except (PyiCloudAPIResponseException, HTTPError) as error:
#     301     msg = "Failed to initiate srp authentication."
# --> 302     raise PyiCloudFailedLoginException(msg, error) from error
#     304 body = response.json()
#     305 salt: bytes = base64.b64decode(body["salt"])
#
# PyiCloudFailedLoginException: ('Failed to initiate srp authentication.', PyiCloudAPIResponseException('Request failed to iCloud'))
